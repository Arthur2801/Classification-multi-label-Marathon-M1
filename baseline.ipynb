# %%
import pandas as pd

# Charger le fichier CSV dans un dataframe
dataframe = pd.read_csv('challenge_filtered.csv')

# Afficher les premières lignes du dataframe
print(dataframe.head())
# Out:
#   code  effectif
# 0    A        50
# 1    B        75
# 2    C        20
# 3    D        40
#   code  effectif
# 0    A        51
# 1    B        76
# 2    C        21
# 3    D        41
#   code  effectif
# 0    A        52
# 1    B        77
# 2    C        22
# 3    D        42
#   code  effectif
# 0    A        53
# 1    B        78
# 2    C        23
# 3    D        43
#   code  effectif
# 0    A        54
# 1    B        79
# 2    C        24
# 3    D        44
#   code  effectif
# 0    A        55
# 1    B        80
# 2    C        25
# 3    D        45
#   code  effectif
# 0    A        56
# 1    B        81
# 2    C        26
# 3    D        46
#   code  effectif
# 0    A        57
# 1    B        82
# 2    C        27
# 3    D        47
#   code  effectif
# 0    A        58
# 1    B        83
# 2    C        28
# 3    D        48
#   code  effectif
# 0    A        59
# 1    B        84
# 2    C        29
# 3    D        49
#   code  effectif
# 0    A        60
# ...
